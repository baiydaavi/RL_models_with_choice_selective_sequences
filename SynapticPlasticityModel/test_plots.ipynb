# %%
# %load_ext autoreload
# %autoreload 2

import os
import requests
import zipfile

from SynapticPlasticityModel.model import run_td_model
from SynapticPlasticityModel.plotting_utils import GenerateTestPlots

# %% [markdown]
# # Download recorded data
# Download sequential and synchronous data for PL-NAc and sequential data for Thal-NAc if recorded data folder does not already exist.

# %%
if not os.path.exists('recorded_data'):
    url = 'https://zenodo.org/record/5784868/files/recorded_data.zip'
    r = requests.get(url, allow_redirects=True)
    open('recorded_data.zip', 'wb').write(r.content)

    with zipfile.ZipFile("recorded_data.zip","r") as zip_ref:
        zip_ref.extractall(".")

    os.remove("recorded_data.zip")

# %% [markdown]
# # Fig 5 plots

# %% [markdown]
# ## PL-NAc sequential data

# %%
results = run_td_model()
TestPlots = GenerateTestPlots(results)
# Out:
# 100%|██████████| 49999/49999 [12:39<00:00, 65.82it/s]

# %%
TestPlots.behavior(start_num_trials=100, num_tr=100)
# Out:
# reward rate = 0.47206

# %%
TestPlots.block_switch()
# Out:
# [0.82995392]

# %%
TestPlots.stay_probability()

# %%
TestPlots.rpe_plot()

# %%
TestPlots.dopamine_regression()
# Out:
# [ 0.61416984 -0.0786534  -0.04209113 -0.0253702  -0.01686325 -0.01314933]

# %%
TestPlots.block_value_plot()

# %% [markdown]
# ## PL-NAc synchronous data

# %%
results = run_td_model(activity_type='synchronous', learning_rate=0.003, frac_decision_neuron=2, temperature=1000)
TestPlots = GenerateTestPlots(results)
# Out:
# 100%|██████████| 49999/49999 [12:53<00:00, 64.68it/s]

# %%
TestPlots.behavior(start_num_trials=100, num_tr=100)
# Out:
# reward rate = 0.43918

# %%
TestPlots.block_switch()
# Out:
# [0.96882856]

# %%
TestPlots.stay_probability()

# %%
TestPlots.rpe_plot()

# %%
TestPlots.dopamine_regression()
# Out:
# [ 0.74003283 -0.02103313 -0.01650046 -0.01429977 -0.01207414 -0.01169524]

# %%
TestPlots.block_value_plot()

# %% [markdown]
# ## Thal-NAc sequential data

# %%
results = run_td_model(data_id='Thal')
TestPlots = GenerateTestPlots(results)
# Out:
# 100%|██████████| 49999/49999 [12:41<00:00, 65.63it/s]

# %%
TestPlots.behavior(start_num_trials=100, num_tr=100)
# Out:
# reward rate = 0.38708

# %%
TestPlots.block_switch()
# Out:
# [0.82038288]

# %%
TestPlots.stay_probability()

# %%
TestPlots.rpe_plot()

# %%
TestPlots.dopamine_regression()
# Out:
# [ 0.66559952 -0.04576961 -0.03327337 -0.02756188 -0.0232091  -0.0214083 ]

# %%
TestPlots.block_value_plot()

# %% [markdown]
# # Fig 6 plots

# %% [markdown]
# ## PL-NAc optogenetic data

# %%
results = run_td_model(is_stimulated=True)
TestPlots = GenerateTestPlots(results)
# Out:
# 100%|██████████| 49999/49999 [12:42<00:00, 65.59it/s]

# %%
TestPlots.choice_regression(mode='optogenetic')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.469421
#          Iterations 6

# %%
TestPlots.stay_probability(mode='optogenetic')
