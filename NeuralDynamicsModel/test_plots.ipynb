# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import requests
import zipfile

from plotting_utils import GenerateTestPlots

# %% [markdown]
# # Download testing data
# Download and unzip the test data if the testing data folder does not exist already.

# %%
if not os.path.exists('testing_data'):
    url = 'https://zenodo.org/record/5774370/files/testing_data.zip'
    r = requests.get(url, allow_redirects=True)
    open('testing_data.zip', 'wb').write(r.content)

    with zipfile.ZipFile("testing_data.zip","r") as zip_ref:
        zip_ref.extractall("testing_data")
# Out:
# 4551

# %% [markdown]
# # Create folder to save test plots

# %%
os.makedirs('test_plots', exist_ok=True)

# %% [markdown]
# # Generate test plots

# %%
GeneratePlots = GenerateTestPlots()
# Out:
#   6%|▌         | 3/50 [00:03<00:47,  1.01s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e4058c58722d> in <module>
# ----> 1 GeneratePlots = GenerateTestPlots()
#
# ~/Google Drive/github/PL-NAc-Meta-RL-model/NeuralDynamicsModel/plotting_utils.py in __init__(self, block_type, mode, num_actions, num_states, num_hidden_units, gamma)
#      63             self.critic_cs.append(np.float32(testing_data['critic_cs']))
#      64             self.actor_hs.append(np.float32(testing_data['actor_hs']))
# ---> 65             self.actor_cs.append(np.float32(testing_data['actor_cs']))
#      66             self.is_stimulateds.append(testing_data['is_stimulateds'])
#      67
#
# ~/opt/anaconda3/envs/PL-NAc-Meta-RL-model/lib/python3.6/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     253                 return format.read_array(bytes,
# ...

# %%
GeneratePlots.behavior(start_num_trials=820, num_tr=100, save='test_plots/Fig7b.pdf')
# Out:
# reward rate = 0.5401866666666667

# %%
GeneratePlots.block_switch(save='test_plots/Fig7c.pdf')
# Out:
# [0.9453749]

# %%
GeneratePlots.rpe_plot(save='test_plots/Fig7d_top.pdf')

# %%
GeneratePlots.dopamine_regression(save='test_plots/Fig7d_bottom.pdf')
# Out:
# [ 7.22213163e-01 -1.01129418e-01  4.01878255e-03 -1.32802634e-03
#  -1.05009000e-03  2.13500059e-04]

# %% [markdown]
# # Plot tests using a fixed block length

# %%
GeneratePlots = GenerateTestPlots(block_type="fixed", mode="optogenetic")
GeneratePlots.logit_rpe(save='test_plots/Fig7f.pdf')
# Out:
# 100%|██████████| 50/50 [00:47<00:00,  1.05it/s]

# %%
GeneratePlots = GenerateTestPlots(block_type="fixed", mode="default")
GeneratePlots.lstm_dynamic_across_blocks_3d(save='test_plots/Fig7g_left.pdf')
# Out:
# 100%|██████████| 50/50 [00:39<00:00,  1.26it/s]
# Fraction of variance explained by the PCA components are [0.709 0.166 0.064]

# %%
GeneratePlots.lstm_dynamic_across_blocks_3d(
    plot_elevation_angle=15, plot_azimuth_angle=10, save='test_plots/Fig7g_right.pdf'
)
# Out:
# Fraction of variance explained by the PCA components are [0.709 0.166 0.064]

# %%
GeneratePlots.actor_lstm_PC_overlap_with_output(save='test_plots/Fig7h.pdf')
# Out:
# Fraction of variance explained by the PCA components are [0.709 0.166 0.064]

# %%
GeneratePlots.regress_lstm_pca_components(save='test_plots/Fig7i.pdf')
# Out:
# Fraction of variance explained by the PCA components are [0.709 0.166 0.064]

# %% [markdown]
# # Plot optogenetic results

# %%
GeneratePlots = GenerateTestPlots(block_type="default", mode="optogenetic")
# Out:
# 100%|██████████| 50/50 [00:43<00:00,  1.14it/s]

# %%
GeneratePlots.stay_probability(mode="optogenetic", save='test_plots/Fig7j.pdf')

# %%
GeneratePlots.choice_regression(mode="optogenetic", save='test_plots/Fig7k.pdf')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.338741
#          Iterations 8
